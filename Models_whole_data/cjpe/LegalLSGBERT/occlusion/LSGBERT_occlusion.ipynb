# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from numpy import load
from keras import layers
from tensorflow import keras
from keras.layers import Input, Layer, GRU, Dropout, Dense
from keras.models import Sequential, Model
import numpy as np

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Thesis/train_data/ILDC_multi.csv')
x_train0 = load("/content/drive/MyDrive/Thesis/Models_whole_data/transformers_sentence_level/LSGBERT_multi_2560_512/LSGBERT_npy_files_cls_multi/LSGBERT_cls_train.npy", allow_pickle = True)
x_dev0 = load("/content/drive/MyDrive/Thesis/Models_whole_data/transformers_sentence_level/LSGBERT_multi_2560_512/LSGBERT_npy_files_cls_multi/LSGBERT_cls_dev.npy", allow_pickle= True)
x_test0 = load("/content/drive/MyDrive/Thesis/Models_whole_data/transformers_sentence_level/LSGBERT_multi_2560_512/LSGBERT_npy_files_cls_multi/LSGBERT_cls_test.npy", allow_pickle= True)

# %%
len(x_test0)
# Out:
# 1517

# %%
len(x_test0[0][1])
# Out:
# 768

# %%
# loading the corresponding label for each case in dataset
dev = dataset.loc[dataset['split'] == 'dev']
train = dataset.loc[dataset['split'] == 'train']
test = dataset.loc[dataset['split'] == 'test']

y_train0 = []
for i in range(train.shape[0]):
    y_train0.append(train.loc[i,'label'])

y_dev0 = []
for i in range(dev.shape[0]):
    y_dev0.append(dev.loc[i+32305,'label'])

y_test0 = []
for i in range(test.shape[0]):
    y_test0.append(test.loc[i+33299,'label'])

# %%
# model.add(AttentionLayer())
text_input = Input(shape=(None,768,), dtype='float32', name='text') #1 sent_input
print("text input",text_input)
l_mask = layers.Masking(mask_value=-99.)(text_input) #2 sent_encoder
print("l_mask",l_mask)
# Which we encoded in a single vector via a LSTM
encoded_text = layers.Bidirectional(GRU(100,return_sequences=True))(l_mask) #3 sent_gru
encoded_text1 = layers.Bidirectional(GRU(100,return_sequences=False))(encoded_text) #4
# out_dense = layers.Dense(200, activation='relu')(encoded_text1) #5 sent_dense
sent_drop = Dropout(0.5,name='sent_dropout')(encoded_text1)
# And we add a softmax classifier on top
out1 = layers.Dense(30, activation='relu')(sent_drop) #7 preds
out = layers.Dense(1, activation='sigmoid')(out1)
model = Model(text_input,out)


model.summary()
# Out:
# text input KerasTensor(type_spec=TensorSpec(shape=(None, None, 768), dtype=tf.float32, name='text'), name='text', description="created by layer 'text'")
# l_mask KerasTensor(type_spec=TensorSpec(shape=(None, None, 768), dtype=tf.float32, name=None), name='masking/mul:0', description="created by layer 'masking'")
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  text (InputLayer)           [(None, None, 768)]       0
#
#  masking (Masking)           (None, None, 768)         0
#
#  bidirectional (Bidirection  (None, None, 200)         522000
#  al)
#
#  bidirectional_1 (Bidirecti  (None, 200)               181200
#  onal)
#
#  sent_dropout (Dropout)      (None, 200)               0
#
#  dense (Dense)               (None, 30)                6030
#
#  dense_1 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 709261 (2.71 MB)
# Trainable params: 709261 (2.71 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.load_weights('/content/drive/MyDrive/Thesis/Models_whole_data/transformers_sentence_level/LSGBERT_multi_2560_512/BIGRU_LSGBERT_cls.h5')

# %%
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['acc'])

# %%
new_test_x = [] #  Queste due liste vuote vengono create per ospitare i nuovi dati di test occlusi.
new_test_y = []
for i in range(len(x_test0)): #  Questo è un loop che scorre attraverso tutti i campioni nei dati di test originali
  full_emb = x_test0[i] #  full_emb è l'embedding completo del campione corrente, che è estratto dai dati di test originali.
  label = y_test0[i] # label è l'etichetta corrispondente al campione corrente, estratta dai dati delle etichette di test originali
  new_test_x.append(full_emb) #  L'embedding completo del campione corrente viene aggiunto alla lista new_test_x, che inizialmente conterrà le versioni non occluse dei dati di input.
  new_test_y.append(label) # L'etichetta corrispondente viene aggiunta alla lista new_test_y
  for j in range(len(full_emb)): #  Questo è un loop interno che scorre attraverso ciascuna dimensione dell'embedding del campione corrente. j è l'indice della dimensione corrente.
    emb_occluded = [] # Viene creata una lista vuota emb_occluded che conterrà l'embedding occluso.
    for k in range(len(full_emb)): # Questo è un altro loop interno che scorre attraverso tutte le dimensioni dell'embedding originale (full_emb).
      if(k==j): # Se l'indice k è uguale all'indice j (cioè stiamo analizzando la stessa dimensione dell'embedding)
        emb_occluded.append(np.zeros(768)) #  viene aggiunto un vettore di zeri (np.zeros(768)) alla lista emb_occluded. In pratica, qui stiamo oscurando una dimensione dell'embedding.
      else:
        emb_occluded.append(full_emb[k]) # Se l'indice k non è uguale a j, viene aggiunta la corrispondente dimensione dell'embedding originale alla lista emb_occluded
  # Alla fine del loop interno, la lista emb_occluded conterrà l'embedding con una delle sue dimensioni oscurata.
    new_test_x.append(emb_occluded) #  L'embedding occluso viene aggiunto alla lista new_test_x.
    new_test_y.append(label) # L'etichetta corrispondente viene nuovamente aggiunta alla lista new_test_y.

# %%
print(y_test0[0])
# Out:
# 1

# %%
print(len(new_test_x[0]),len(new_test_x[1]),len(new_test_x[2]),len(new_test_x[3]),len(new_test_x[10]))
# Out:
# 8 8 8 8 5

# %%
def new_test_generator(): # function to generate batches of corresponding batch size
    x_list= new_test_x
    y_list =  new_test_y
    # Generate batches
    while True:
        for b in range(batches_per_epoch_test):
            if(b == batches_per_epoch_test-1): # An extra if else statement just to manage the last batch as it's size might not be equal to batch size
              longest_index = num_sequences_test - 1
              timesteps = len(max(new_test_x[:longest_index + 1][-batch_size_test:], key=len))
              x_train = np.full((longest_index - b*batch_size_test, timesteps, num_features), -99.)
              y_train = np.zeros((longest_index - b*batch_size_test,  1))
              for i in range(longest_index - b*batch_size_test):
                  li = b * batch_size_test + i
                  x_train[i, 0:len(x_list[li]), :] = x_list[li]
                  y_train[i] = y_list[li]
            else:
                longest_index = (b + 1) * batch_size_test - 1
                timesteps = len(max(new_test_x[:(b + 1) * batch_size_test][-batch_size_test:], key=len))
                x_train = np.full((batch_size_test, timesteps, num_features), -99.)
                y_train = np.zeros((batch_size_test,  1))
                # padding the vectors with respect to the maximum sequence of each batch and not the whole test data
                for i in range(batch_size_test):
                    li = b * batch_size_test + i
                    x_train[i, 0:len(x_list[li]), :] = x_list[li]
                    y_train[i] = y_list[li]
            yield x_train, y_train

# %%
num_sequences_test = len(new_test_x)
print(num_sequences_test)
batch_size_test = 52
if(num_sequences_test%batch_size_test == 0):
  batches_per_epoch_test = int(num_sequences_test/batch_size_test)
else:
  batches_per_epoch_test = int(num_sequences_test/batch_size_test) + 1
#assert batch_size_val * batches_per_epoch_val == num_sequences_val
num_features= 768
model.evaluate_generator(new_test_generator(), steps= batches_per_epoch_test)
# Out:
# 18238
# <ipython-input-14-cd324557cd41>:10: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   model.evaluate_generator(new_test_generator(), steps= batches_per_epoch_test)
# [0.481068879365921, 0.7842298746109009]

# %%
preds = model.predict_generator(new_test_generator(), steps= batches_per_epoch_test)
print(len(preds))
# Out:
# <ipython-input-15-7d4a2c1f7140>:1: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   preds = model.predict_generator(new_test_generator(), steps= batches_per_epoch_test)
# 18237

# %%
scores = []  #Inizializza una lista vuota chiamata scores che conterrà gli score di occlusione per ciascun campione nel set di test.

startpt = 0 # Inizializza un indice startpt che tiene traccia della posizione corrente nell'array delle previsioni (preds).
for i in range(len(x_test0)-1): #  Inizia un loop che scorre attraverso ciascun campione nel set di test. x_test0 contiene gli embedding dei campioni, quindi len(x_test0) rappresenta il numero totale di campioni nel set di test.
  n_emb_for_this_doc = x_test0[i].shape[0] # Ottiene il numero di embedding (dimensioni dell'embedding) per il campione corrente.
  tot_embs = n_emb_for_this_doc + 1 # Calcola il numero totale di embedding inclusi il campione originale e i campioni occlusi.
  act_pred = preds[startpt] > 0.5 # Determina se la previsione fatta dal modello per il campione originale è maggiore di 0.5, indicando che il modello ha classificato il campione come positivo.

  chunk_scores = [] #  Inizializza una lista vuota chunk_scores che conterrà gli score di occlusione per ciascun "chunk" (campione originale e campioni occlusi) del campione corrente.
  for j in range(tot_embs-1): # Inizia un loop che scorre attraverso ciascun "chunk" (campione occluso) del campione corrente.
    if(act_pred): # se è vero (il modello ha previsto positivo per il campione originale)
      chunk_scores.append(-1*(preds[startpt+j+1]-preds[startpt])) # Viene calcolato uno score di occlusione come la differenza negativa tra la previsione del modello per il chunk occluso e la previsione del modello per il campione originale. Questo è il valore -1*(preds[startpt+j+1]-preds[startpt]).
    else:
      chunk_scores.append(preds[startpt+j+1]-preds[startpt]) # Viene calcolato uno score di occlusione come la differenza positiva tra la previsione del modello per il chunk occluso e la previsione del modello per il campione originale (preds[startpt+j+1]-preds[startpt]).

  scores.append(chunk_scores) # Aggiunge la lista chunk_scores (contenente gli score di occlusione per il campione corrente) alla lista globale scores.
  startpt += tot_embs # Aggiorna l'indice startpt in modo che punti alla posizione successiva nelle previsioni (preds) per il prossimo campione.

# In breve, questa parte di codice calcola gli score di occlusione per ogni campione nel set di test, dove uno score di occlusione rappresenta quanto una dimensione dell'embedding influisce sulla previsione del modello.
# Gli score vengono calcolati confrontando le previsioni del modello per i chunk occlusi con le previsioni per il campione originale.

# %%
print(len(scores))
# Out:
# 1516

# %%
l_scores = [] #  Inizializza una lista vuota chiamata l_scores che conterrà gli score di occlusione semplificati.
for s in scores: # Inizia un loop che scorre attraverso ogni elemento nella lista scores. Ogni elemento s in questo caso è una lista di score di occlusione per un determinato campione.
  c_s =[] # Inizializza una nuova lista vuota chiamata c_s che conterrà gli score di occlusione semplificati per il campione corrente.
  for c in s: # Inizia un loop interno che scorre attraverso ogni elemento c (che rappresenta uno score di occlusione) nella lista s (score di occlusione per un campione specifico).
    c_s.append(c[0]) # : Aggiunge il primo elemento di ogni score di occlusione c alla lista c_s. Questo passo semplifica gli score di occlusione a un valore numerico singolo (il primo elemento dell'array c), che rappresenta l'effetto di occlusione su una dimensione dell'embedding.
    # Alla fine del loop interno, la lista c_s conterrà gli score di occlusione semplificati per il campione corrente.
  l_scores.append(c_s) #  Aggiunge la lista c_s (contenente gli score di occlusione semplificati per un campione) alla lista l_scores.

# In sintesi, questo pezzo di codice raccoglie gli score di occlusione semplificati da una struttura più complessa in una nuova lista l_scores, dove ogni elemento in l_scores è una lista di score di occlusione semplificati per un campione specifico.

# %%
print(l_scores[0])
# Out:
# [0.014234722, 0.002370298, 0.12819034, -0.03661126, -0.008173764, 0.033132315, 0.03257233, 0.015708506]

# %%
scores = []
act_predictions = []

startpt = 0
for i in range(len(x_test0)):
  n_emb_for_this_doc = x_test0[i].shape[0]
  tot_embs = n_emb_for_this_doc + 1
  act_pred = preds[startpt] > 0.5
  act_predictions.append(act_pred)
  startpt += tot_embs

# %%
for i in range(len(act_predictions)):
  print("{:} true = {:}, pred = {:}, iscorrect = {:}".format(i+1,y_test0[i],act_predictions[i], y_test0[i] == act_predictions[i]))
# Out:
# 1 true = 1, pred = [ True], iscorrect = [ True]
# 2 true = 0, pred = [False], iscorrect = [ True]
# 3 true = 0, pred = [False], iscorrect = [ True]
# 4 true = 0, pred = [False], iscorrect = [ True]
# 5 true = 1, pred = [ True], iscorrect = [ True]
# 6 true = 0, pred = [False], iscorrect = [ True]
# 7 true = 0, pred = [False], iscorrect = [ True]
# 8 true = 0, pred = [False], iscorrect = [ True]
# 9 true = 1, pred = [False], iscorrect = [False]
# 10 true = 0, pred = [False], iscorrect = [ True]
# 11 true = 1, pred = [ True], iscorrect = [ True]
# 12 true = 0, pred = [False], iscorrect = [ True]
# 13 true = 1, pred = [ True], iscorrect = [ True]
# 14 true = 1, pred = [ True], iscorrect = [ True]
# 15 true = 0, pred = [False], iscorrect = [ True]
# 16 true = 0, pred = [False], iscorrect = [ True]
# 17 true = 1, pred = [ True], iscorrect = [ True]
# 18 true = 1, pred = [ True], iscorrect = [ True]
# 19 true = 1, pred = [ True], iscorrect = [ True]
# 20 true = 1, pred = [False], iscorrect = [False]
# 21 true = 0, pred = [False], iscorrect = [ True]
# 22 true = 1, pred = [ True], iscorrect = [ True]
# 23 true = 1, pred = [ True], iscorrect = [ True]
# 24 true = 1, pred = [False], iscorrect = [False]
# 25 true = 1, pred = [ True], iscorrect = [ True]
# 26 true = 0, pred = [False], iscorrect = [ True]
# 27 true = 1, pred = [ True], iscorrect = [ True]
# 28 true = 1, pred = [False], iscorrect = [False]
# 29 true = 0, pred = [False], iscorrect = [ True]
# 30 true = 1, pred = [ True], iscorrect = [ True]
# 31 true = 1, pred = [False], iscorrect = [False]
# 32 true = 1, pred = [ True], iscorrect = [ True]
# 33 true = 0, pred = [ True], iscorrect = [False]
# 34 true = 0, pred = [False], iscorrect = [ True]
# 35 true = 1, pred = [False], iscorrect = [False]
# 36 true = 0, pred = [False], iscorrect = [ True]
# 37 true = 1, pred = [False], iscorrect = [False]
# 38 true = 1, pred = [ True], iscorrect = [ True]
# 39 true = 0, pred = [False], iscorrect = [ True]
# 40 true = 1, pred = [ True], iscorrect = [ True]
# 41 true = 0, pred = [False], iscorrect = [ True]
# 42 true = 0, pred = [False], iscorrect = [ True]
# 43 true = 1, pred = [False], iscorrect = [False]
# 44 true = 1, pred = [False], iscorrect = [False]
# 45 true = 1, pred = [False], iscorrect = [False]
# 46 true = 1, pred = [False], iscorrect = [False]
# 47 true = 0, pred = [False], iscorrect = [ True]
# 48 true = 1, pred = [ True], iscorrect = [ True]
# 49 true = 1, pred = [ True], iscorrect = [ True]
# 50 true = 0, pred = [False], iscorrect = [ True]
# 51 true = 1, pred = [ True], iscorrect = [ True]
# 52 true = 1, pred = [ True], iscorrect = [ True]
# 53 true = 0, pred = [False], iscorrect = [ True]
# 54 true = 0, pred = [False], iscorrect = [ True]
# 55 true = 0, pred = [False], iscorrect = [ True]
# 56 true = 0, pred = [ True], iscorrect = [False]
# 57 true = 0, pred = [False], iscorrect = [ True]
# 58 true = 0, pred = [False], iscorrect = [ True]
# 59 true = 1, pred = [ True], iscorrect = [ True]
# 60 true = 0, pred = [False], iscorrect = [ True]
# 61 true = 1, pred = [False], iscorrect = [False]
# 62 true = 0, pred = [False], iscorrect = [ True]
# 63 true = 0, pred = [False], iscorrect = [ True]
# 64 true = 1, pred = [ True], iscorrect = [ True]
# 65 true = 0, pred = [False], iscorrect = [ True]
# 66 true = 0, pred = [False], iscorrect = [ True]
# 67 true = 0, pred = [False], iscorrect = [ True]
# 68 true = 0, pred = [False], iscorrect = [ True]
# 69 true = 1, pred = [ True], iscorrect = [ True]
# 70 true = 1, pred = [ True], iscorrect = [ True]
# 71 true = 0, pred = [False], iscorrect = [ True]
# 72 true = 1, pred = [ True], iscorrect = [ True]
# 73 true = 1, pred = [False], iscorrect = [False]
# 74 true = 0, pred = [False], iscorrect = [ True]
# 75 true = 1, pred = [ True], iscorrect = [ True]
# 76 true = 0, pred = [False], iscorrect = [ True]
# 77 true = 0, pred = [False], iscorrect = [ True]
# 78 true = 1, pred = [False], iscorrect = [False]
# 79 true = 0, pred = [False], iscorrect = [ True]
# 80 true = 1, pred = [ True], iscorrect = [ True]
# 81 true = 0, pred = [False], iscorrect = [ True]
# 82 true = 1, pred = [False], iscorrect = [False]
# 83 true = 0, pred = [False], iscorrect = [ True]
# 84 true = 1, pred = [False], iscorrect = [False]
# 85 true = 0, pred = [ True], iscorrect = [False]
# 86 true = 0, pred = [False], iscorrect = [ True]
# 87 true = 0, pred = [False], iscorrect = [ True]
# 88 true = 1, pred = [ True], iscorrect = [ True]
# 89 true = 1, pred = [False], iscorrect = [False]
# 90 true = 1, pred = [ True], iscorrect = [ True]
# 91 true = 0, pred = [False], iscorrect = [ True]
# 92 true = 1, pred = [ True], iscorrect = [ True]
# 93 true = 0, pred = [False], iscorrect = [ True]
# 94 true = 1, pred = [ True], iscorrect = [ True]
# 95 true = 0, pred = [False], iscorrect = [ True]
# 96 true = 1, pred = [ True], iscorrect = [ True]
# 97 true = 1, pred = [False], iscorrect = [False]
# 98 true = 0, pred = [False], iscorrect = [ True]
# 99 true = 1, pred = [False], iscorrect = [False]
# 100 true = 0, pred = [ True], iscorrect = [False]
# 101 true = 1, pred = [False], iscorrect = [False]
# 102 true = 1, pred = [ True], iscorrect = [ True]
# 103 true = 1, pred = [ True], iscorrect = [ True]
# 104 true = 1, pred = [False], iscorrect = [False]
# 105 true = 0, pred = [False], iscorrect = [ True]
# 106 true = 1, pred = [ True], iscorrect = [ True]
# 107 true = 1, pred = [ True], iscorrect = [ True]
# 108 true = 0, pred = [ True], iscorrect = [False]
# 109 true = 0, pred = [False], iscorrect = [ True]
# 110 true = 0, pred = [False], iscorrect = [ True]
# 111 true = 0, pred = [False], iscorrect = [ True]
# 112 true = 0, pred = [False], iscorrect = [ True]
# 113 true = 0, pred = [False], iscorrect = [ True]
# 114 true = 1, pred = [False], iscorrect = [False]
# 115 true = 1, pred = [ True], iscorrect = [ True]
# 116 true = 1, pred = [ True], iscorrect = [ True]
# 117 true = 0, pred = [False], iscorrect = [ True]
# 118 true = 1, pred = [False], iscorrect = [False]
# 119 true = 0, pred = [False], iscorrect = [ True]
# 120 true = 0, pred = [False], iscorrect = [ True]
# 121 true = 1, pred = [ True], iscorrect = [ True]
# 122 true = 0, pred = [False], iscorrect = [ True]
# 123 true = 0, pred = [ True], iscorrect = [False]
# 124 true = 0, pred = [False], iscorrect = [ True]
# 125 true = 1, pred = [ True], iscorrect = [ True]
# 126 true = 1, pred = [ True], iscorrect = [ True]
# 127 true = 1, pred = [ True], iscorrect = [ True]
# 128 true = 1, pred = [False], iscorrect = [False]
# 129 true = 1, pred = [ True], iscorrect = [ True]
# 130 true = 1, pred = [ True], iscorrect = [ True]
# 131 true = 1, pred = [ True], iscorrect = [ True]
# 132 true = 0, pred = [False], iscorrect = [ True]
# 133 true = 1, pred = [ True], iscorrect = [ True]
# 134 true = 0, pred = [False], iscorrect = [ True]
# 135 true = 1, pred = [ True], iscorrect = [ True]
# 136 true = 1, pred = [ True], iscorrect = [ True]
# 137 true = 0, pred = [False], iscorrect = [ True]
# 138 true = 0, pred = [False], iscorrect = [ True]
# 139 true = 1, pred = [ True], iscorrect = [ True]
# 140 true = 0, pred = [False], iscorrect = [ True]
# 141 true = 1, pred = [ True], iscorrect = [ True]
# 142 true = 0, pred = [False], iscorrect = [ True]
# 143 true = 1, pred = [False], iscorrect = [False]
# 144 true = 0, pred = [False], iscorrect = [ True]
# 145 true = 1, pred = [ True], iscorrect = [ True]
# 146 true = 0, pred = [False], iscorrect = [ True]
# 147 true = 0, pred = [False], iscorrect = [ True]
# 148 true = 0, pred = [False], iscorrect = [ True]
# 149 true = 1, pred = [ True], iscorrect = [ True]
# 150 true = 1, pred = [ True], iscorrect = [ True]
# 151 true = 1, pred = [ True], iscorrect = [ True]
# 152 true = 0, pred = [ True], iscorrect = [False]
# 153 true = 0, pred = [ True], iscorrect = [False]
# 154 true = 0, pred = [False], iscorrect = [ True]
# 155 true = 0, pred = [False], iscorrect = [ True]
# 156 true = 0, pred = [False], iscorrect = [ True]
# 157 true = 0, pred = [False], iscorrect = [ True]
# 158 true = 0, pred = [False], iscorrect = [ True]
# 159 true = 0, pred = [False], iscorrect = [ True]
# 160 true = 1, pred = [False], iscorrect = [False]
# 161 true = 0, pred = [False], iscorrect = [ True]
# 162 true = 1, pred = [False], iscorrect = [False]
# 163 true = 0, pred = [ True], iscorrect = [False]
# 164 true = 0, pred = [False], iscorrect = [ True]
# 165 true = 0, pred = [ True], iscorrect = [False]
# 166 true = 0, pred = [False], iscorrect = [ True]
# 167 true = 1, pred = [ True], iscorrect = [ True]
# 168 true = 0, pred = [False], iscorrect = [ True]
# 169 true = 0, pred = [ True], iscorrect = [False]
# 170 true = 0, pred = [False], iscorrect = [ True]
# 171 true = 1, pred = [False], iscorrect = [False]
# 172 true = 0, pred = [False], iscorrect = [ True]
# 173 true = 1, pred = [ True], iscorrect = [ True]
# 174 true = 1, pred = [ True], iscorrect = [ True]
# 175 true = 1, pred = [ True], iscorrect = [ True]
# 176 true = 0, pred = [False], iscorrect = [ True]
# 177 true = 1, pred = [ True], iscorrect = [ True]
# 178 true = 0, pred = [False], iscorrect = [ True]
# 179 true = 0, pred = [False], iscorrect = [ True]
# 180 true = 0, pred = [ True], iscorrect = [False]
# 181 true = 1, pred = [ True], iscorrect = [ True]
# 182 true = 1, pred = [ True], iscorrect = [ True]
# 183 true = 1, pred = [False], iscorrect = [False]
# 184 true = 1, pred = [ True], iscorrect = [ True]
# 185 true = 0, pred = [ True], iscorrect = [False]
# 186 true = 0, pred = [ True], iscorrect = [False]
# 187 true = 1, pred = [ True], iscorrect = [ True]
# 188 true = 0, pred = [False], iscorrect = [ True]
# 189 true = 0, pred = [False], iscorrect = [ True]
# 190 true = 0, pred = [False], iscorrect = [ True]
# 191 true = 0, pred = [False], iscorrect = [ True]
# 192 true = 0, pred = [False], iscorrect = [ True]
# 193 true = 0, pred = [False], iscorrect = [ True]
# 194 true = 1, pred = [False], iscorrect = [False]
# 195 true = 1, pred = [ True], iscorrect = [ True]
# 196 true = 0, pred = [False], iscorrect = [ True]
# 197 true = 1, pred = [False], iscorrect = [False]
# 198 true = 1, pred = [ True], iscorrect = [ True]
# 199 true = 0, pred = [False], iscorrect = [ True]
# 200 true = 1, pred = [False], iscorrect = [False]
# 201 true = 1, pred = [ True], iscorrect = [ True]
# 202 true = 0, pred = [False], iscorrect = [ True]
# 203 true = 0, pred = [ True], iscorrect = [False]
# 204 true = 0, pred = [False], iscorrect = [ True]
# 205 true = 1, pred = [ True], iscorrect = [ True]
# 206 true = 0, pred = [False], iscorrect = [ True]
# 207 true = 0, pred = [False], iscorrect = [ True]
# 208 true = 0, pred = [False], iscorrect = [ True]
# 209 true = 1, pred = [ True], iscorrect = [ True]
# 210 true = 1, pred = [ True], iscorrect = [ True]
# 211 true = 1, pred = [ True], iscorrect = [ True]
# 212 true = 1, pred = [ True], iscorrect = [ True]
# 213 true = 0, pred = [ True], iscorrect = [False]
# 214 true = 0, pred = [False], iscorrect = [ True]
# 215 true = 0, pred = [False], iscorrect = [ True]
# 216 true = 0, pred = [ True], iscorrect = [False]
# 217 true = 1, pred = [ True], iscorrect = [ True]
# 218 true = 0, pred = [False], iscorrect = [ True]
# 219 true = 1, pred = [ True], iscorrect = [ True]
# 220 true = 0, pred = [False], iscorrect = [ True]
# 221 true = 1, pred = [ True], iscorrect = [ True]
# 222 true = 0, pred = [False], iscorrect = [ True]
# 223 true = 1, pred = [ True], iscorrect = [ True]
# 224 true = 0, pred = [False], iscorrect = [ True]
# 225 true = 0, pred = [False], iscorrect = [ True]
# 226 true = 0, pred = [False], iscorrect = [ True]
# 227 true = 0, pred = [False], iscorrect = [ True]
# 228 true = 0, pred = [ True], iscorrect = [False]
# 229 true = 0, pred = [False], iscorrect = [ True]
# 230 true = 0, pred = [False], iscorrect = [ True]
# 231 true = 1, pred = [ True], iscorrect = [ True]
# 232 true = 0, pred = [False], iscorrect = [ True]
# 233 true = 0, pred = [False], iscorrect = [ True]
# 234 true = 1, pred = [False], iscorrect = [False]
# 235 true = 1, pred = [ True], iscorrect = [ True]
# 236 true = 1, pred = [ True], iscorrect = [ True]
# 237 true = 0, pred = [False], iscorrect = [ True]
# 238 true = 1, pred = [ True], iscorrect = [ True]
# 239 true = 1, pred = [ True], iscorrect = [ True]
# 240 true = 1, pred = [False], iscorrect = [False]
# 241 true = 1, pred = [ True], iscorrect = [ True]
# 242 true = 0, pred = [False], iscorrect = [ True]
# 243 true = 1, pred = [ True], iscorrect = [ True]
# 244 true = 1, pred = [ True], iscorrect = [ True]
# 245 true = 1, pred = [ True], iscorrect = [ True]
# 246 true = 1, pred = [ True], iscorrect = [ True]
# 247 true = 1, pred = [ True], iscorrect = [ True]
# 248 true = 0, pred = [False], iscorrect = [ True]
# 249 true = 1, pred = [ True], iscorrect = [ True]
# 250 true = 1, pred = [ True], iscorrect = [ True]
# 251 true = 1, pred = [ True], iscorrect = [ True]
# 252 true = 1, pred = [ True], iscorrect = [ True]
# 253 true = 1, pred = [False], iscorrect = [False]
# 254 true = 0, pred = [ True], iscorrect = [False]
# 255 true = 0, pred = [False], iscorrect = [ True]
# 256 true = 1, pred = [ True], iscorrect = [ True]
# 257 true = 1, pred = [ True], iscorrect = [ True]
# 258 true = 1, pred = [ True], iscorrect = [ True]
# 259 true = 1, pred = [ True], iscorrect = [ True]
# 260 true = 0, pred = [False], iscorrect = [ True]
# 261 true = 0, pred = [False], iscorrect = [ True]
# 262 true = 1, pred = [False], iscorrect = [False]
# 263 true = 0, pred = [False], iscorrect = [ True]
# 264 true = 1, pred = [ True], iscorrect = [ True]
# 265 true = 0, pred = [ True], iscorrect = [False]
# 266 true = 0, pred = [False], iscorrect = [ True]
# 267 true = 1, pred = [ True], iscorrect = [ True]
# 268 true = 0, pred = [False], iscorrect = [ True]
# 269 true = 0, pred = [False], iscorrect = [ True]
# 270 true = 0, pred = [False], iscorrect = [ True]
# 271 true = 0, pred = [False], iscorrect = [ True]
# 272 true = 0, pred = [False], iscorrect = [ True]
# 273 true = 1, pred = [ True], iscorrect = [ True]
# 274 true = 1, pred = [ True], iscorrect = [ True]
# 275 true = 0, pred = [False], iscorrect = [ True]
# 276 true = 0, pred = [False], iscorrect = [ True]
# 277 true = 1, pred = [ True], iscorrect = [ True]
# 278 true = 1, pred = [ True], iscorrect = [ True]
# 279 true = 0, pred = [ True], iscorrect = [False]
# 280 true = 0, pred = [False], iscorrect = [ True]
# 281 true = 1, pred = [ True], iscorrect = [ True]
# 282 true = 1, pred = [ True], iscorrect = [ True]
# 283 true = 1, pred = [False], iscorrect = [False]
# 284 true = 0, pred = [False], iscorrect = [ True]
# 285 true = 0, pred = [False], iscorrect = [ True]
# 286 true = 1, pred = [False], iscorrect = [False]
# 287 true = 0, pred = [False], iscorrect = [ True]
# 288 true = 0, pred = [False], iscorrect = [ True]
# 289 true = 1, pred = [ True], iscorrect = [ True]
# 290 true = 0, pred = [False], iscorrect = [ True]
# 291 true = 1, pred = [ True], iscorrect = [ True]
# 292 true = 1, pred = [ True], iscorrect = [ True]
# 293 true = 1, pred = [False], iscorrect = [False]
# 294 true = 0, pred = [False], iscorrect = [ True]
# 295 true = 1, pred = [ True], iscorrect = [ True]
# 296 true = 0, pred = [ True], iscorrect = [False]
# 297 true = 1, pred = [False], iscorrect = [False]
# 298 true = 0, pred = [False], iscorrect = [ True]
# 299 true = 0, pred = [False], iscorrect = [ True]
# 300 true = 0, pred = [False], iscorrect = [ True]
# 301 true = 1, pred = [ True], iscorrect = [ True]
# 302 true = 0, pred = [False], iscorrect = [ True]
# 303 true = 1, pred = [ True], iscorrect = [ True]
# 304 true = 0, pred = [ True], iscorrect = [False]
# 305 true = 1, pred = [ True], iscorrect = [ True]
# 306 true = 1, pred = [ True], iscorrect = [ True]
# 307 true = 0, pred = [False], iscorrect = [ True]
# 308 true = 1, pred = [ True], iscorrect = [ True]
# 309 true = 0, pred = [ True], iscorrect = [False]
# 310 true = 0, pred = [False], iscorrect = [ True]
# 311 true = 0, pred = [False], iscorrect = [ True]
# 312 true = 1, pred = [False], iscorrect = [False]
# 313 true = 0, pred = [False], iscorrect = [ True]
# 314 true = 0, pred = [False], iscorrect = [ True]
# 315 true = 1, pred = [ True], iscorrect = [ True]
# 316 true = 0, pred = [ True], iscorrect = [False]
# 317 true = 1, pred = [ True], iscorrect = [ True]
# 318 true = 0, pred = [False], iscorrect = [ True]
# 319 true = 0, pred = [False], iscorrect = [ True]
# 320 true = 1, pred = [ True], iscorrect = [ True]
# 321 true = 0, pred = [ True], iscorrect = [False]
# 322 true = 1, pred = [ True], iscorrect = [ True]
# 323 true = 1, pred = [False], iscorrect = [False]
# 324 true = 1, pred = [False], iscorrect = [False]
# 325 true = 1, pred = [ True], iscorrect = [ True]
# 326 true = 1, pred = [ True], iscorrect = [ True]
# 327 true = 0, pred = [False], iscorrect = [ True]
# 328 true = 0, pred = [False], iscorrect = [ True]
# 329 true = 0, pred = [False], iscorrect = [ True]
# 330 true = 1, pred = [ True], iscorrect = [ True]
# 331 true = 1, pred = [ True], iscorrect = [ True]
# 332 true = 1, pred = [ True], iscorrect = [ True]
# 333 true = 0, pred = [False], iscorrect = [ True]
# 334 true = 1, pred = [False], iscorrect = [False]
# 335 true = 1, pred = [ True], iscorrect = [ True]
# 336 true = 0, pred = [False], iscorrect = [ True]
# 337 true = 1, pred = [False], iscorrect = [False]
# 338 true = 0, pred = [False], iscorrect = [ True]
# 339 true = 0, pred = [False], iscorrect = [ True]
# 340 true = 1, pred = [ True], iscorrect = [ True]
# 341 true = 0, pred = [False], iscorrect = [ True]
# 342 true = 0, pred = [ True], iscorrect = [False]
# 343 true = 0, pred = [False], iscorrect = [ True]
# 344 true = 0, pred = [ True], iscorrect = [False]
# 345 true = 0, pred = [False], iscorrect = [ True]
# 346 true = 0, pred = [False], iscorrect = [ True]
# 347 true = 1, pred = [False], iscorrect = [False]
# 348 true = 1, pred = [ True], iscorrect = [ True]
# 349 true = 0, pred = [False], iscorrect = [ True]
# 350 true = 0, pred = [False], iscorrect = [ True]
# 351 true = 1, pred = [ True], iscorrect = [ True]
# 352 true = 1, pred = [ True], iscorrect = [ True]
# 353 true = 0, pred = [False], iscorrect = [ True]
# 354 true = 1, pred = [ True], iscorrect = [ True]
# 355 true = 1, pred = [ True], iscorrect = [ True]
# 356 true = 0, pred = [False], iscorrect = [ True]
# 357 true = 1, pred = [ True], iscorrect = [ True]
# 358 true = 0, pred = [False], iscorrect = [ True]
# 359 true = 1, pred = [ True], iscorrect = [ True]
# 360 true = 0, pred = [False], iscorrect = [ True]
# 361 true = 1, pred = [ True], iscorrect = [ True]
# 362 true = 1, pred = [ True], iscorrect = [ True]
# 363 true = 0, pred = [False], iscorrect = [ True]
# 364 true = 1, pred = [ True], iscorrect = [ True]
# 365 true = 0, pred = [False], iscorrect = [ True]
# 366 true = 1, pred = [ True], iscorrect = [ True]
# 367 true = 0, pred = [ True], iscorrect = [False]
# 368 true = 0, pred = [False], iscorrect = [ True]
# 369 true = 1, pred = [ True], iscorrect = [ True]
# 370 true = 0, pred = [False], iscorrect = [ True]
# 371 true = 1, pred = [ True], iscorrect = [ True]
# 372 true = 1, pred = [ True], iscorrect = [ True]
# 373 true = 1, pred = [ True], iscorrect = [ True]
# 374 true = 0, pred = [False], iscorrect = [ True]
# 375 true = 0, pred = [False], iscorrect = [ True]
# 376 true = 1, pred = [ True], iscorrect = [ True]
# 377 true = 1, pred = [ True], iscorrect = [ True]
# 378 true = 1, pred = [ True], iscorrect = [ True]
# 379 true = 1, pred = [ True], iscorrect = [ True]
# 380 true = 0, pred = [False], iscorrect = [ True]
# 381 true = 0, pred = [False], iscorrect = [ True]
# 382 true = 1, pred = [ True], iscorrect = [ True]
# 383 true = 1, pred = [False], iscorrect = [False]
# 384 true = 0, pred = [False], iscorrect = [ True]
# 385 true = 1, pred = [ True], iscorrect = [ True]
# 386 true = 1, pred = [False], iscorrect = [False]
# 387 true = 1, pred = [ True], iscorrect = [ True]
# 388 true = 1, pred = [ True], iscorrect = [ True]
# 389 true = 0, pred = [False], iscorrect = [ True]
# 390 true = 1, pred = [ True], iscorrect = [ True]
# 391 true = 1, pred = [False], iscorrect = [False]
# 392 true = 1, pred = [ True], iscorrect = [ True]
# 393 true = 1, pred = [ True], iscorrect = [ True]
# 394 true = 1, pred = [ True], iscorrect = [ True]
# 395 true = 0, pred = [False], iscorrect = [ True]
# 396 true = 0, pred = [False], iscorrect = [ True]
# 397 true = 0, pred = [False], iscorrect = [ True]
# 398 true = 0, pred = [False], iscorrect = [ True]
# 399 true = 1, pred = [False], iscorrect = [False]
# 400 true = 1, pred = [ True], iscorrect = [ True]
# 401 true = 1, pred = [ True], iscorrect = [ True]
# 402 true = 0, pred = [False], iscorrect = [ True]
# 403 true = 0, pred = [False], iscorrect = [ True]
# 404 true = 0, pred = [False], iscorrect = [ True]
# 405 true = 0, pred = [False], iscorrect = [ True]
# 406 true = 1, pred = [False], iscorrect = [False]
# 407 true = 1, pred = [ True], iscorrect = [ True]
# 408 true = 0, pred = [False], iscorrect = [ True]
# 409 true = 1, pred = [ True], iscorrect = [ True]
# 410 true = 0, pred = [False], iscorrect = [ True]
# 411 true = 0, pred = [False], iscorrect = [ True]
# 412 true = 0, pred = [False], iscorrect = [ True]
# 413 true = 1, pred = [False], iscorrect = [False]
# 414 true = 0, pred = [False], iscorrect = [ True]
# 415 true = 0, pred = [False], iscorrect = [ True]
# 416 true = 0, pred = [False], iscorrect = [ True]
# 417 true = 1, pred = [ True], iscorrect = [ True]
# 418 true = 1, pred = [False], iscorrect = [False]
# 419 true = 1, pred = [ True], iscorrect = [ True]
# 420 true = 0, pred = [ True], iscorrect = [False]
# 421 true = 1, pred = [False], iscorrect = [False]
# 422 true = 1, pred = [ True], iscorrect = [ True]
# 423 true = 1, pred = [ True], iscorrect = [ True]
# 424 true = 1, pred = [ True], iscorrect = [ True]
# 425 true = 1, pred = [ True], iscorrect = [ True]
# 426 true = 0, pred = [False], iscorrect = [ True]
# 427 true = 1, pred = [ True], iscorrect = [ True]
# 428 true = 1, pred = [ True], iscorrect = [ True]
# 429 true = 1, pred = [ True], iscorrect = [ True]
# 430 true = 1, pred = [ True], iscorrect = [ True]
# 431 true = 1, pred = [ True], iscorrect = [ True]
# 432 true = 1, pred = [ True], iscorrect = [ True]
# 433 true = 1, pred = [ True], iscorrect = [ True]
# 434 true = 1, pred = [ True], iscorrect = [ True]
# 435 true = 1, pred = [ True], iscorrect = [ True]
# 436 true = 0, pred = [False], iscorrect = [ True]
# 437 true = 0, pred = [False], iscorrect = [ True]
# 438 true = 1, pred = [ True], iscorrect = [ True]
# 439 true = 0, pred = [False], iscorrect = [ True]
# 440 true = 0, pred = [False], iscorrect = [ True]
# 441 true = 0, pred = [False], iscorrect = [ True]
# 442 true = 0, pred = [False], iscorrect = [ True]
# 443 true = 1, pred = [ True], iscorrect = [ True]
# 444 true = 1, pred = [ True], iscorrect = [ True]
# 445 true = 0, pred = [False], iscorrect = [ True]
# 446 true = 1, pred = [ True], iscorrect = [ True]
# 447 true = 0, pred = [False], iscorrect = [ True]
# 448 true = 0, pred = [False], iscorrect = [ True]
# 449 true = 1, pred = [ True], iscorrect = [ True]
# 450 true = 0, pred = [False], iscorrect = [ True]
# 451 true = 0, pred = [False], iscorrect = [ True]
# 452 true = 0, pred = [False], iscorrect = [ True]
# 453 true = 1, pred = [False], iscorrect = [False]
# 454 true = 0, pred = [False], iscorrect = [ True]
# 455 true = 1, pred = [ True], iscorrect = [ True]
# 456 true = 1, pred = [False], iscorrect = [False]
# 457 true = 0, pred = [ True], iscorrect = [False]
# 458 true = 1, pred = [ True], iscorrect = [ True]
# 459 true = 1, pred = [ True], iscorrect = [ True]
# 460 true = 1, pred = [ True], iscorrect = [ True]
# 461 true = 1, pred = [ True], iscorrect = [ True]
# 462 true = 1, pred = [ True], iscorrect = [ True]
# 463 true = 1, pred = [ True], iscorrect = [ True]
# 464 true = 0, pred = [False], iscorrect = [ True]
# 465 true = 1, pred = [ True], iscorrect = [ True]
# 466 true = 0, pred = [False], iscorrect = [ True]
# 467 true = 0, pred = [False], iscorrect = [ True]
# 468 true = 1, pred = [ True], iscorrect = [ True]
# 469 true = 0, pred = [False], iscorrect = [ True]
# 470 true = 0, pred = [False], iscorrect = [ True]
# 471 true = 1, pred = [ True], iscorrect = [ True]
# 472 true = 1, pred = [ True], iscorrect = [ True]
# 473 true = 0, pred = [False], iscorrect = [ True]
# 474 true = 0, pred = [False], iscorrect = [ True]
# 475 true = 0, pred = [False], iscorrect = [ True]
# 476 true = 0, pred = [False], iscorrect = [ True]
# 477 true = 1, pred = [ True], iscorrect = [ True]
# 478 true = 0, pred = [False], iscorrect = [ True]
# 479 true = 0, pred = [False], iscorrect = [ True]
# 480 true = 1, pred = [ True], iscorrect = [ True]
# 481 true = 1, pred = [False], iscorrect = [False]
# 482 true = 1, pred = [ True], iscorrect = [ True]
# 483 true = 1, pred = [ True], iscorrect = [ True]
# 484 true = 1, pred = [ True], iscorrect = [ True]
# 485 true = 1, pred = [ True], iscorrect = [ True]
# 486 true = 1, pred = [False], iscorrect = [False]
# 487 true = 1, pred = [ True], iscorrect = [ True]
# 488 true = 1, pred = [ True], iscorrect = [ True]
# 489 true = 1, pred = [False], iscorrect = [False]
# 490 true = 0, pred = [False], iscorrect = [ True]
# 491 true = 1, pred = [ True], iscorrect = [ True]
# 492 true = 0, pred = [False], iscorrect = [ True]
# 493 true = 0, pred = [False], iscorrect = [ True]
# 494 true = 0, pred = [False], iscorrect = [ True]
# 495 true = 1, pred = [ True], iscorrect = [ True]
# 496 true = 1, pred = [False], iscorrect = [False]
# 497 true = 1, pred = [ True], iscorrect = [ True]
# 498 true = 0, pred = [False], iscorrect = [ True]
# 499 true = 1, pred = [ True], iscorrect = [ True]
# 500 true = 1, pred = [ True], iscorrect = [ True]
# 501 true = 1, pred = [ True], iscorrect = [ True]
# 502 true = 1, pred = [ True], iscorrect = [ True]
# 503 true = 1, pred = [ True], iscorrect = [ True]
# 504 true = 1, pred = [ True], iscorrect = [ True]
# 505 true = 1, pred = [ True], iscorrect = [ True]
# 506 true = 0, pred = [ True], iscorrect = [False]
# 507 true = 1, pred = [False], iscorrect = [False]
# 508 true = 0, pred = [False], iscorrect = [ True]
# 509 true = 1, pred = [ True], iscorrect = [ True]
# 510 true = 0, pred = [False], iscorrect = [ True]
# 511 true = 0, pred = [False], iscorrect = [ True]
# 512 true = 0, pred = [ True], iscorrect = [False]
# 513 true = 1, pred = [ True], iscorrect = [ True]
# 514 true = 0, pred = [ True], iscorrect = [False]
# 515 true = 0, pred = [False], iscorrect = [ True]
# 516 true = 1, pred = [False], iscorrect = [False]
# 517 true = 1, pred = [ True], iscorrect = [ True]
# 518 true = 0, pred = [False], iscorrect = [ True]
# 519 true = 0, pred = [False], iscorrect = [ True]
# 520 true = 0, pred = [ True], iscorrect = [False]
# 521 true = 0, pred = [False], iscorrect = [ True]
# 522 true = 0, pred = [False], iscorrect = [ True]
# 523 true = 1, pred = [ True], iscorrect = [ True]
# 524 true = 0, pred = [False], iscorrect = [ True]
# 525 true = 0, pred = [False], iscorrect = [ True]
# 526 true = 0, pred = [False], iscorrect = [ True]
# 527 true = 0, pred = [False], iscorrect = [ True]
# 528 true = 1, pred = [False], iscorrect = [False]
# 529 true = 0, pred = [False], iscorrect = [ True]
# 530 true = 0, pred = [False], iscorrect = [ True]
# 531 true = 0, pred = [False], iscorrect = [ True]
# 532 true = 0, pred = [ True], iscorrect = [False]
# 533 true = 0, pred = [ True], iscorrect = [False]
# 534 true = 1, pred = [ True], iscorrect = [ True]
# 535 true = 1, pred = [False], iscorrect = [False]
# 536 true = 0, pred = [ True], iscorrect = [False]
# 537 true = 1, pred = [ True], iscorrect = [ True]
# 538 true = 0, pred = [False], iscorrect = [ True]
# 539 true = 1, pred = [ True], iscorrect = [ True]
# 540 true = 1, pred = [False], iscorrect = [False]
# 541 true = 0, pred = [False], iscorrect = [ True]
# 542 true = 1, pred = [ True], iscorrect = [ True]
# 543 true = 0, pred = [False], iscorrect = [ True]
# 544 true = 1, pred = [False], iscorrect = [False]
# 545 true = 0, pred = [ True], iscorrect = [False]
# 546 true = 1, pred = [ True], iscorrect = [ True]
# 547 true = 0, pred = [False], iscorrect = [ True]
# 548 true = 1, pred = [ True], iscorrect = [ True]
# 549 true = 1, pred = [ True], iscorrect = [ True]
# 550 true = 1, pred = [False], iscorrect = [False]
# 551 true = 1, pred = [ True], iscorrect = [ True]
# 552 true = 0, pred = [ True], iscorrect = [False]
# 553 true = 0, pred = [False], iscorrect = [ True]
# 554 true = 1, pred = [ True], iscorrect = [ True]
# 555 true = 0, pred = [False], iscorrect = [ True]
# 556 true = 0, pred = [False], iscorrect = [ True]
# 557 true = 0, pred = [ True], iscorrect = [False]
# 558 true = 0, pred = [False], iscorrect = [ True]
# 559 true = 0, pred = [False], iscorrect = [ True]
# 560 true = 0, pred = [False], iscorrect = [ True]
# 561 true = 1, pred = [ True], iscorrect = [ True]
# 562 true = 1, pred = [ True], iscorrect = [ True]
# 563 true = 0, pred = [False], iscorrect = [ True]
# 564 true = 0, pred = [False], iscorrect = [ True]
# 565 true = 1, pred = [ True], iscorrect = [ True]
# 566 true = 1, pred = [ True], iscorrect = [ True]
# 567 true = 0, pred = [False], iscorrect = [ True]
# 568 true = 0, pred = [False], iscorrect = [ True]
# 569 true = 0, pred = [False], iscorrect = [ True]
# 570 true = 0, pred = [False], iscorrect = [ True]
# 571 true = 0, pred = [ True], iscorrect = [False]
# 572 true = 1, pred = [ True], iscorrect = [ True]
# 573 true = 0, pred = [False], iscorrect = [ True]
# 574 true = 1, pred = [False], iscorrect = [False]
# 575 true = 0, pred = [ True], iscorrect = [False]
# 576 true = 0, pred = [False], iscorrect = [ True]
# 577 true = 1, pred = [ True], iscorrect = [ True]
# 578 true = 0, pred = [False], iscorrect = [ True]
# 579 true = 0, pred = [False], iscorrect = [ True]
# 580 true = 1, pred = [False], iscorrect = [False]
# 581 true = 0, pred = [False], iscorrect = [ True]
# 582 true = 0, pred = [False], iscorrect = [ True]
# 583 true = 0, pred = [False], iscorrect = [ True]
# 584 true = 1, pred = [False], iscorrect = [False]
# 585 true = 1, pred = [False], iscorrect = [False]
# 586 true = 1, pred = [ True], iscorrect = [ True]
# 587 true = 1, pred = [ True], iscorrect = [ True]
# 588 true = 0, pred = [False], iscorrect = [ True]
# 589 true = 0, pred = [False], iscorrect = [ True]
# 590 true = 1, pred = [ True], iscorrect = [ True]
# 591 true = 0, pred = [False], iscorrect = [ True]
# 592 true = 1, pred = [ True], iscorrect = [ True]
# 593 true = 1, pred = [ True], iscorrect = [ True]
# 594 true = 1, pred = [ True], iscorrect = [ True]
# 595 true = 0, pred = [False], iscorrect = [ True]
# 596 true = 0, pred = [False], iscorrect = [ True]
# 597 true = 0, pred = [False], iscorrect = [ True]
# 598 true = 0, pred = [False], iscorrect = [ True]
# 599 true = 0, pred = [False], iscorrect = [ True]
# 600 true = 0, pred = [False], iscorrect = [ True]
# 601 true = 1, pred = [ True], iscorrect = [ True]
# 602 true = 1, pred = [False], iscorrect = [False]
# 603 true = 1, pred = [ True], iscorrect = [ True]
# 604 true = 0, pred = [False], iscorrect = [ True]
# 605 true = 1, pred = [False], iscorrect = [False]
# 606 true = 1, pred = [ True], iscorrect = [ True]
# 607 true = 0, pred = [ True], iscorrect = [False]
# 608 true = 0, pred = [False], iscorrect = [ True]
# 609 true = 0, pred = [ True], iscorrect = [False]
# 610 true = 0, pred = [ True], iscorrect = [False]
# 611 true = 0, pred = [False], iscorrect = [ True]
# 612 true = 1, pred = [ True], iscorrect = [ True]
# 613 true = 0, pred = [False], iscorrect = [ True]
# 614 true = 1, pred = [False], iscorrect = [False]
# 615 true = 0, pred = [False], iscorrect = [ True]
# 616 true = 1, pred = [ True], iscorrect = [ True]
# 617 true = 1, pred = [False], iscorrect = [False]
# 618 true = 1, pred = [ True], iscorrect = [ True]
# 619 true = 1, pred = [ True], iscorrect = [ True]
# 620 true = 1, pred = [ True], iscorrect = [ True]
# 621 true = 1, pred = [False], iscorrect = [False]
# 622 true = 1, pred = [False], iscorrect = [False]
# 623 true = 0, pred = [False], iscorrect = [ True]
# 624 true = 1, pred = [ True], iscorrect = [ True]
# 625 true = 1, pred = [ True], iscorrect = [ True]
# 626 true = 1, pred = [ True], iscorrect = [ True]
# 627 true = 0, pred = [False], iscorrect = [ True]
# 628 true = 1, pred = [ True], iscorrect = [ True]
# 629 true = 1, pred = [ True], iscorrect = [ True]
# 630 true = 0, pred = [False], iscorrect = [ True]
# 631 true = 0, pred = [False], iscorrect = [ True]
# 632 true = 1, pred = [ True], iscorrect = [ True]
# 633 true = 1, pred = [ True], iscorrect = [ True]
# 634 true = 1, pred = [False], iscorrect = [False]
# 635 true = 1, pred = [False], iscorrect = [False]
# 636 true = 1, pred = [ True], iscorrect = [ True]
# 637 true = 0, pred = [False], iscorrect = [ True]
# 638 true = 0, pred = [False], iscorrect = [ True]
# 639 true = 1, pred = [ True], iscorrect = [ True]
# 640 true = 0, pred = [False], iscorrect = [ True]
# 641 true = 0, pred = [False], iscorrect = [ True]
# 642 true = 0, pred = [False], iscorrect = [ True]
# 643 true = 0, pred = [False], iscorrect = [ True]
# 644 true = 1, pred = [ True], iscorrect = [ True]
# 645 true = 1, pred = [False], iscorrect = [False]
# 646 true = 1, pred = [ True], iscorrect = [ True]
# 647 true = 0, pred = [ True], iscorrect = [False]
# 648 true = 0, pred = [False], iscorrect = [ True]
# 649 true = 0, pred = [False], iscorrect = [ True]
# 650 true = 0, pred = [False], iscorrect = [ True]
# 651 true = 0, pred = [False], iscorrect = [ True]
# 652 true = 0, pred = [False], iscorrect = [ True]
# 653 true = 0, pred = [False], iscorrect = [ True]
# 654 true = 1, pred = [False], iscorrect = [False]
# 655 true = 0, pred = [False], iscorrect = [ True]
# 656 true = 0, pred = [False], iscorrect = [ True]
# 657 true = 1, pred = [ True], iscorrect = [ True]
# 658 true = 0, pred = [False], iscorrect = [ True]
# 659 true = 0, pred = [ True], iscorrect = [False]
# 660 true = 1, pred = [ True], iscorrect = [ True]
# 661 true = 0, pred = [False], iscorrect = [ True]
# 662 true = 0, pred = [False], iscorrect = [ True]
# 663 true = 1, pred = [ True], iscorrect = [ True]
# 664 true = 0, pred = [False], iscorrect = [ True]
# 665 true = 1, pred = [ True], iscorrect = [ True]
# 666 true = 0, pred = [False], iscorrect = [ True]
# 667 true = 0, pred = [False], iscorrect = [ True]
# 668 true = 1, pred = [ True], iscorrect = [ True]
# 669 true = 1, pred = [ True], iscorrect = [ True]
# 670 true = 0, pred = [False], iscorrect = [ True]
# 671 true = 1, pred = [ True], iscorrect = [ True]
# 672 true = 0, pred = [ True], iscorrect = [False]
# 673 true = 0, pred = [False], iscorrect = [ True]
# 674 true = 0, pred = [False], iscorrect = [ True]
# 675 true = 1, pred = [ True], iscorrect = [ True]
# 676 true = 0, pred = [False], iscorrect = [ True]
# 677 true = 1, pred = [ True], iscorrect = [ True]
# 678 true = 0, pred = [False], iscorrect = [ True]
# 679 true = 1, pred = [ True], iscorrect = [ True]
# 680 true = 0, pred = [False], iscorrect = [ True]
# 681 true = 0, pred = [False], iscorrect = [ True]
# 682 true = 1, pred = [ True], iscorrect = [ True]
# 683 true = 1, pred = [ True], iscorrect = [ True]
# 684 true = 1, pred = [False], iscorrect = [False]
# 685 true = 0, pred = [ True], iscorrect = [False]
# 686 true = 1, pred = [ True], iscorrect = [ True]
# 687 true = 1, pred = [ True], iscorrect = [ True]
# 688 true = 1, pred = [ True], iscorrect = [ True]
# 689 true = 1, pred = [ True], iscorrect = [ True]
# 690 true = 0, pred = [ True], iscorrect = [False]
# 691 true = 1, pred = [ True], iscorrect = [ True]
# 692 true = 1, pred = [ True], iscorrect = [ True]
# 693 true = 1, pred = [False], iscorrect = [False]
# 694 true = 0, pred = [False], iscorrect = [ True]
# 695 true = 1, pred = [ True], iscorrect = [ True]
# 696 true = 0, pred = [ True], iscorrect = [False]
# 697 true = 1, pred = [ True], iscorrect = [ True]
# 698 true = 1, pred = [ True], iscorrect = [ True]
# 699 true = 1, pred = [ True], iscorrect = [ True]
# 700 true = 0, pred = [False], iscorrect = [ True]
# 701 true = 1, pred = [ True], iscorrect = [ True]
# 702 true = 1, pred = [ True], iscorrect = [ True]
# 703 true = 1, pred = [ True], iscorrect = [ True]
# 704 true = 1, pred = [False], iscorrect = [False]
# 705 true = 0, pred = [False], iscorrect = [ True]
# 706 true = 1, pred = [ True], iscorrect = [ True]
# 707 true = 1, pred = [ True], iscorrect = [ True]
# 708 true = 0, pred = [False], iscorrect = [ True]
# 709 true = 0, pred = [ True], iscorrect = [False]
# 710 true = 0, pred = [False], iscorrect = [ True]
# 711 true = 1, pred = [ True], iscorrect = [ True]
# 712 true = 1, pred = [ True], iscorrect = [ True]
# 713 true = 0, pred = [False], iscorrect = [ True]
# 714 true = 1, pred = [ True], iscorrect = [ True]
# 715 true = 0, pred = [False], iscorrect = [ True]
# 716 true = 0, pred = [False], iscorrect = [ True]
# 717 true = 0, pred = [False], iscorrect = [ True]
# 718 true = 0, pred = [ True], iscorrect = [False]
# 719 true = 1, pred = [ True], iscorrect = [ True]
# 720 true = 0, pred = [ True], iscorrect = [False]
# 721 true = 1, pred = [False], iscorrect = [False]
# 722 true = 0, pred = [False], iscorrect = [ True]
# 723 true = 0, pred = [ True], iscorrect = [False]
# 724 true = 1, pred = [False], iscorrect = [False]
# 725 true = 1, pred = [False], iscorrect = [False]
# 726 true = 1, pred = [False], iscorrect = [False]
# 727 true = 1, pred = [ True], iscorrect = [ True]
# 728 true = 0, pred = [False], iscorrect = [ True]
# 729 true = 1, pred = [False], iscorrect = [False]
# 730 true = 1, pred = [ True], iscorrect = [ True]
# 731 true = 1, pred = [ True], iscorrect = [ True]
# 732 true = 0, pred = [False], iscorrect = [ True]
# 733 true = 1, pred = [ True], iscorrect = [ True]
# 734 true = 1, pred = [False], iscorrect = [False]
# 735 true = 1, pred = [ True], iscorrect = [ True]
# 736 true = 1, pred = [ True], iscorrect = [ True]
# 737 true = 1, pred = [ True], iscorrect = [ True]
# 738 true = 0, pred = [False], iscorrect = [ True]
# 739 true = 1, pred = [ True], iscorrect = [ True]
# 740 true = 1, pred = [ True], iscorrect = [ True]
# 741 true = 0, pred = [ True], iscorrect = [False]
# 742 true = 0, pred = [False], iscorrect = [ True]
# 743 true = 0, pred = [False], iscorrect = [ True]
# 744 true = 0, pred = [False], iscorrect = [ True]
# 745 true = 0, pred = [False], iscorrect = [ True]
# 746 true = 0, pred = [False], iscorrect = [ True]
# 747 true = 1, pred = [ True], iscorrect = [ True]
# 748 true = 1, pred = [ True], iscorrect = [ True]
# 749 true = 0, pred = [False], iscorrect = [ True]
# 750 true = 0, pred = [False], iscorrect = [ True]
# 751 true = 1, pred = [ True], iscorrect = [ True]
# 752 true = 0, pred = [ True], iscorrect = [False]
# 753 true = 0, pred = [False], iscorrect = [ True]
# 754 true = 1, pred = [ True], iscorrect = [ True]
# 755 true = 0, pred = [False], iscorrect = [ True]
# 756 true = 1, pred = [ True], iscorrect = [ True]
# 757 true = 0, pred = [False], iscorrect = [ True]
# 758 true = 1, pred = [ True], iscorrect = [ True]
# 759 true = 0, pred = [False], iscorrect = [ True]
# 760 true = 1, pred = [ True], iscorrect = [ True]
# 761 true = 0, pred = [ True], iscorrect = [False]
# 762 true = 1, pred = [False], iscorrect = [False]
# 763 true = 1, pred = [False], iscorrect = [False]
# 764 true = 0, pred = [False], iscorrect = [ True]
# 765 true = 1, pred = [ True], iscorrect = [ True]
# 766 true = 1, pred = [ True], iscorrect = [ True]
# 767 true = 0, pred = [ True], iscorrect = [False]
# 768 true = 1, pred = [False], iscorrect = [False]
# 769 true = 1, pred = [ True], iscorrect = [ True]
# 770 true = 0, pred = [ True], iscorrect = [False]
# 771 true = 0, pred = [False], iscorrect = [ True]
# 772 true = 1, pred = [ True], iscorrect = [ True]
# 773 true = 1, pred = [ True], iscorrect = [ True]
# 774 true = 1, pred = [ True], iscorrect = [ True]
# 775 true = 1, pred = [False], iscorrect = [False]
# 776 true = 1, pred = [ True], iscorrect = [ True]
# 777 true = 0, pred = [False], iscorrect = [ True]
# 778 true = 0, pred = [False], iscorrect = [ True]
# 779 true = 0, pred = [ True], iscorrect = [False]
# 780 true = 1, pred = [False], iscorrect = [False]
# 781 true = 0, pred = [ True], iscorrect = [False]
# 782 true = 0, pred = [False], iscorrect = [ True]
# 783 true = 1, pred = [False], iscorrect = [False]
# 784 true = 0, pred = [False], iscorrect = [ True]
# 785 true = 1, pred = [ True], iscorrect = [ True]
# 786 true = 0, pred = [False], iscorrect = [ True]
# 787 true = 1, pred = [False], iscorrect = [False]
# 788 true = 1, pred = [False], iscorrect = [False]
# 789 true = 0, pred = [False], iscorrect = [ True]
# 790 true = 1, pred = [ True], iscorrect = [ True]
# 791 true = 0, pred = [ True], iscorrect = [False]
# 792 true = 1, pred = [ True], iscorrect = [ True]
# 793 true = 0, pred = [False], iscorrect = [ True]
# 794 true = 0, pred = [False], iscorrect = [ True]
# 795 true = 0, pred = [False], iscorrect = [ True]
# 796 true = 0, pred = [False], iscorrect = [ True]
# 797 true = 1, pred = [ True], iscorrect = [ True]
# 798 true = 0, pred = [False], iscorrect = [ True]
# 799 true = 1, pred = [ True], iscorrect = [ True]
# 800 true = 1, pred = [ True], iscorrect = [ True]
# 801 true = 1, pred = [ True], iscorrect = [ True]
# 802 true = 0, pred = [False], iscorrect = [ True]
# 803 true = 0, pred = [False], iscorrect = [ True]
# 804 true = 0, pred = [False], iscorrect = [ True]
# 805 true = 0, pred = [False], iscorrect = [ True]
# 806 true = 1, pred = [False], iscorrect = [False]
# 807 true = 0, pred = [False], iscorrect = [ True]
# 808 true = 0, pred = [False], iscorrect = [ True]
# 809 true = 1, pred = [False], iscorrect = [False]
# 810 true = 0, pred = [False], iscorrect = [ True]
# 811 true = 1, pred = [ True], iscorrect = [ True]
# 812 true = 0, pred = [False], iscorrect = [ True]
# 813 true = 0, pred = [False], iscorrect = [ True]
# 814 true = 0, pred = [False], iscorrect = [ True]
# 815 true = 1, pred = [ True], iscorrect = [ True]
# 816 true = 1, pred = [ True], iscorrect = [ True]
# 817 true = 0, pred = [False], iscorrect = [ True]
# 818 true = 0, pred = [False], iscorrect = [ True]
# 819 true = 1, pred = [ True], iscorrect = [ True]
# 820 true = 1, pred = [ True], iscorrect = [ True]
# 821 true = 0, pred = [False], iscorrect = [ True]
# 822 true = 0, pred = [False], iscorrect = [ True]
# 823 true = 0, pred = [False], iscorrect = [ True]
# 824 true = 1, pred = [ True], iscorrect = [ True]
# 825 true = 0, pred = [False], iscorrect = [ True]
# 826 true = 1, pred = [ True], iscorrect = [ True]
# 827 true = 0, pred = [False], iscorrect = [ True]
# 828 true = 0, pred = [False], iscorrect = [ True]
# 829 true = 1, pred = [ True], iscorrect = [ True]
# 830 true = 1, pred = [ True], iscorrect = [ True]
# 831 true = 1, pred = [False], iscorrect = [False]
# 832 true = 0, pred = [False], iscorrect = [ True]
# 833 true = 0, pred = [False], iscorrect = [ True]
# 834 true = 0, pred = [False], iscorrect = [ True]
# 835 true = 1, pred = [ True], iscorrect = [ True]
# 836 true = 1, pred = [False], iscorrect = [False]
# 837 true = 0, pred = [ True], iscorrect = [False]
# 838 true = 1, pred = [ True], iscorrect = [ True]
# 839 true = 1, pred = [ True], iscorrect = [ True]
# 840 true = 0, pred = [False], iscorrect = [ True]
# 841 true = 1, pred = [False], iscorrect = [False]
# 842 true = 1, pred = [ True], iscorrect = [ True]
# 843 true = 0, pred = [False], iscorrect = [ True]
# 844 true = 0, pred = [False], iscorrect = [ True]
# 845 true = 0, pred = [ True], iscorrect = [False]
# 846 true = 1, pred = [False], iscorrect = [False]
# 847 true = 0, pred = [False], iscorrect = [ True]
# 848 true = 1, pred = [ True], iscorrect = [ True]
# 849 true = 1, pred = [False], iscorrect = [False]
# 850 true = 1, pred = [False], iscorrect = [False]
# 851 true = 0, pred = [False], iscorrect = [ True]
# 852 true = 1, pred = [ True], iscorrect = [ True]
# 853 true = 0, pred = [False], iscorrect = [ True]
# 854 true = 1, pred = [ True], iscorrect = [ True]
# 855 true = 0, pred = [ True], iscorrect = [False]
# 856 true = 0, pred = [False], iscorrect = [ True]
# 857 true = 0, pred = [False], iscorrect = [ True]
# 858 true = 1, pred = [ True], iscorrect = [ True]
# 859 true = 1, pred = [False], iscorrect = [False]
# 860 true = 0, pred = [False], iscorrect = [ True]
# 861 true = 1, pred = [ True], iscorrect = [ True]
# 862 true = 0, pred = [False], iscorrect = [ True]
# 863 true = 1, pred = [ True], iscorrect = [ True]
# 864 true = 0, pred = [ True], iscorrect = [False]
# 865 true = 1, pred = [ True], iscorrect = [ True]
# 866 true = 0, pred = [False], iscorrect = [ True]
# 867 true = 1, pred = [ True], iscorrect = [ True]
# 868 true = 1, pred = [ True], iscorrect = [ True]
# 869 true = 0, pred = [False], iscorrect = [ True]
# 870 true = 1, pred = [ True], iscorrect = [ True]
# 871 true = 0, pred = [ True], iscorrect = [False]
# 872 true = 1, pred = [False], iscorrect = [False]
# 873 true = 1, pred = [ True], iscorrect = [ True]
# 874 true = 1, pred = [ True], iscorrect = [ True]
# 875 true = 0, pred = [False], iscorrect = [ True]
# 876 true = 0, pred = [False], iscorrect = [ True]
# 877 true = 0, pred = [False], iscorrect = [ True]
# 878 true = 1, pred = [False], iscorrect = [False]
# 879 true = 0, pred = [False], iscorrect = [ True]
# 880 true = 0, pred = [False], iscorrect = [ True]
# 881 true = 0, pred = [False], iscorrect = [ True]
# 882 true = 0, pred = [ True], iscorrect = [False]
# 883 true = 0, pred = [False], iscorrect = [ True]
# 884 true = 0, pred = [False], iscorrect = [ True]
# 885 true = 0, pred = [False], iscorrect = [ True]
# 886 true = 0, pred = [False], iscorrect = [ True]
# 887 true = 1, pred = [ True], iscorrect = [ True]
# 888 true = 0, pred = [False], iscorrect = [ True]
# 889 true = 0, pred = [False], iscorrect = [ True]
# 890 true = 0, pred = [False], iscorrect = [ True]
# 891 true = 0, pred = [False], iscorrect = [ True]
# 892 true = 1, pred = [ True], iscorrect = [ True]
# 893 true = 1, pred = [ True], iscorrect = [ True]
# 894 true = 1, pred = [ True], iscorrect = [ True]
# 895 true = 1, pred = [False], iscorrect = [False]
# 896 true = 0, pred = [False], iscorrect = [ True]
# 897 true = 0, pred = [False], iscorrect = [ True]
# 898 true = 0, pred = [False], iscorrect = [ True]
# 899 true = 1, pred = [False], iscorrect = [False]
# 900 true = 1, pred = [ True], iscorrect = [ True]
# 901 true = 1, pred = [ True], iscorrect = [ True]
# 902 true = 0, pred = [False], iscorrect = [ True]
# 903 true = 0, pred = [False], iscorrect = [ True]
# 904 true = 0, pred = [False], iscorrect = [ True]
# 905 true = 0, pred = [False], iscorrect = [ True]
# 906 true = 1, pred = [ True], iscorrect = [ True]
# 907 true = 0, pred = [False], iscorrect = [ True]
# 908 true = 1, pred = [False], iscorrect = [False]
# 909 true = 0, pred = [False], iscorrect = [ True]
# 910 true = 1, pred = [False], iscorrect = [False]
# 911 true = 0, pred = [False], iscorrect = [ True]
# 912 true = 1, pred = [False], iscorrect = [False]
# 913 true = 0, pred = [False], iscorrect = [ True]
# 914 true = 0, pred = [False], iscorrect = [ True]
# 915 true = 1, pred = [False], iscorrect = [False]
# 916 true = 0, pred = [False], iscorrect = [ True]
# 917 true = 0, pred = [False], iscorrect = [ True]
# 918 true = 0, pred = [False], iscorrect = [ True]
# 919 true = 1, pred = [ True], iscorrect = [ True]
# 920 true = 1, pred = [ True], iscorrect = [ True]
# 921 true = 0, pred = [False], iscorrect = [ True]
# 922 true = 0, pred = [False], iscorrect = [ True]
# 923 true = 1, pred = [ True], iscorrect = [ True]
# 924 true = 1, pred = [ True], iscorrect = [ True]
# 925 true = 0, pred = [False], iscorrect = [ True]
# 926 true = 1, pred = [ True], iscorrect = [ True]
# 927 true = 0, pred = [False], iscorrect = [ True]
# 928 true = 1, pred = [ True], iscorrect = [ True]
# 929 true = 0, pred = [False], iscorrect = [ True]
# 930 true = 0, pred = [False], iscorrect = [ True]
# 931 true = 0, pred = [False], iscorrect = [ True]
# 932 true = 0, pred = [False], iscorrect = [ True]
# 933 true = 0, pred = [False], iscorrect = [ True]
# 934 true = 0, pred = [False], iscorrect = [ True]
# 935 true = 0, pred = [False], iscorrect = [ True]
# 936 true = 0, pred = [ True], iscorrect = [False]
# 937 true = 0, pred = [False], iscorrect = [ True]
# 938 true = 0, pred = [ True], iscorrect = [False]
# 939 true = 1, pred = [False], iscorrect = [False]
# 940 true = 1, pred = [False], iscorrect = [False]
# 941 true = 0, pred = [False], iscorrect = [ True]
# 942 true = 1, pred = [ True], iscorrect = [ True]
# 943 true = 0, pred = [False], iscorrect = [ True]
# 944 true = 1, pred = [False], iscorrect = [False]
# 945 true = 0, pred = [False], iscorrect = [ True]
# 946 true = 0, pred = [ True], iscorrect = [False]
# 947 true = 1, pred = [ True], iscorrect = [ True]
# 948 true = 1, pred = [ True], iscorrect = [ True]
# 949 true = 1, pred = [ True], iscorrect = [ True]
# 950 true = 1, pred = [False], iscorrect = [False]
# 951 true = 0, pred = [False], iscorrect = [ True]
# 952 true = 1, pred = [ True], iscorrect = [ True]
# 953 true = 1, pred = [ True], iscorrect = [ True]
# 954 true = 1, pred = [ True], iscorrect = [ True]
# 955 true = 1, pred = [ True], iscorrect = [ True]
# 956 true = 1, pred = [ True], iscorrect = [ True]
# 957 true = 1, pred = [False], iscorrect = [False]
# 958 true = 0, pred = [False], iscorrect = [ True]
# 959 true = 0, pred = [False], iscorrect = [ True]
# 960 true = 0, pred = [False], iscorrect = [ True]
# 961 true = 1, pred = [ True], iscorrect = [ True]
# 962 true = 1, pred = [ True], iscorrect = [ True]
# ...
# 1205 true = 0, pred = [False], iscorrect = [ True]
# 1206 true = 1, pred = [False], iscorrect = [False]
# 1207 true = 0, pred = [False], iscorrect = [ True]
# 1208 true = 1, pred = [ True], iscorrect = [ True]
# 1209 true = 1, pred = [False], iscorrect = [False]
# 1210 true = 1, pred = [ True], iscorrect = [ True]
# 1211 true = 0, pred = [False], iscorrect = [ True]
# 1212 true = 0, pred = [False], iscorrect = [ True]
# 1213 true = 0, pred = [False], iscorrect = [ True]
# 1214 true = 0, pred = [False], iscorrect = [ True]
# 1215 true = 0, pred = [False], iscorrect = [ True]
# 1216 true = 1, pred = [ True], iscorrect = [ True]
# 1217 true = 1, pred = [ True], iscorrect = [ True]
# 1218 true = 0, pred = [False], iscorrect = [ True]
# 1219 true = 1, pred = [ True], iscorrect = [ True]
# 1220 true = 0, pred = [False], iscorrect = [ True]
# 1221 true = 1, pred = [ True], iscorrect = [ True]
# 1222 true = 1, pred = [ True], iscorrect = [ True]
# 1223 true = 0, pred = [False], iscorrect = [ True]
# 1224 true = 1, pred = [ True], iscorrect = [ True]
# 1225 true = 0, pred = [False], iscorrect = [ True]
# 1226 true = 0, pred = [False], iscorrect = [ True]
# 1227 true = 1, pred = [ True], iscorrect = [ True]
# 1228 true = 0, pred = [False], iscorrect = [ True]
# 1229 true = 0, pred = [ True], iscorrect = [False]
# 1230 true = 1, pred = [False], iscorrect = [False]
# 1231 true = 0, pred = [ True], iscorrect = [False]
# 1232 true = 0, pred = [ True], iscorrect = [False]
# 1233 true = 1, pred = [False], iscorrect = [False]
# 1234 true = 1, pred = [ True], iscorrect = [ True]
# 1235 true = 0, pred = [False], iscorrect = [ True]
# 1236 true = 1, pred = [False], iscorrect = [False]
# 1237 true = 1, pred = [ True], iscorrect = [ True]
# 1238 true = 0, pred = [False], iscorrect = [ True]
# 1239 true = 0, pred = [ True], iscorrect = [False]
# 1240 true = 0, pred = [False], iscorrect = [ True]
# 1241 true = 0, pred = [ True], iscorrect = [False]
# 1242 true = 1, pred = [ True], iscorrect = [ True]
# 1243 true = 1, pred = [ True], iscorrect = [ True]
# 1244 true = 0, pred = [False], iscorrect = [ True]
# 1245 true = 1, pred = [ True], iscorrect = [ True]
# 1246 true = 0, pred = [False], iscorrect = [ True]
# 1247 true = 1, pred = [ True], iscorrect = [ True]
# 1248 true = 0, pred = [False], iscorrect = [ True]
# 1249 true = 1, pred = [ True], iscorrect = [ True]
# 1250 true = 1, pred = [ True], iscorrect = [ True]
# 1251 true = 1, pred = [ True], iscorrect = [ True]
# 1252 true = 1, pred = [False], iscorrect = [False]
# 1253 true = 1, pred = [ True], iscorrect = [ True]
# 1254 true = 1, pred = [ True], iscorrect = [ True]
# 1255 true = 0, pred = [False], iscorrect = [ True]
# 1256 true = 0, pred = [False], iscorrect = [ True]
# 1257 true = 0, pred = [False], iscorrect = [ True]
# 1258 true = 0, pred = [False], iscorrect = [ True]
# 1259 true = 1, pred = [ True], iscorrect = [ True]
# 1260 true = 1, pred = [ True], iscorrect = [ True]
# 1261 true = 1, pred = [ True], iscorrect = [ True]
# 1262 true = 1, pred = [ True], iscorrect = [ True]
# 1263 true = 1, pred = [ True], iscorrect = [ True]
# 1264 true = 1, pred = [ True], iscorrect = [ True]
# 1265 true = 0, pred = [False], iscorrect = [ True]
# 1266 true = 0, pred = [False], iscorrect = [ True]
# 1267 true = 0, pred = [False], iscorrect = [ True]
# 1268 true = 1, pred = [False], iscorrect = [False]
# 1269 true = 1, pred = [ True], iscorrect = [ True]
# 1270 true = 0, pred = [False], iscorrect = [ True]
# 1271 true = 1, pred = [ True], iscorrect = [ True]
# 1272 true = 0, pred = [False], iscorrect = [ True]
# 1273 true = 0, pred = [False], iscorrect = [ True]
# 1274 true = 1, pred = [ True], iscorrect = [ True]
# 1275 true = 1, pred = [ True], iscorrect = [ True]
# 1276 true = 0, pred = [ True], iscorrect = [False]
# 1277 true = 1, pred = [ True], iscorrect = [ True]
# 1278 true = 1, pred = [False], iscorrect = [False]
# 1279 true = 1, pred = [False], iscorrect = [False]
# 1280 true = 0, pred = [False], iscorrect = [ True]
# 1281 true = 1, pred = [ True], iscorrect = [ True]
# 1282 true = 0, pred = [False], iscorrect = [ True]
# 1283 true = 1, pred = [ True], iscorrect = [ True]
# 1284 true = 0, pred = [False], iscorrect = [ True]
# 1285 true = 0, pred = [False], iscorrect = [ True]
# 1286 true = 1, pred = [ True], iscorrect = [ True]
# 1287 true = 1, pred = [ True], iscorrect = [ True]
# 1288 true = 0, pred = [False], iscorrect = [ True]
# 1289 true = 1, pred = [ True], iscorrect = [ True]
# 1290 true = 0, pred = [False], iscorrect = [ True]
# 1291 true = 0, pred = [False], iscorrect = [ True]
# 1292 true = 1, pred = [False], iscorrect = [False]
# 1293 true = 1, pred = [ True], iscorrect = [ True]
# 1294 true = 1, pred = [ True], iscorrect = [ True]
# 1295 true = 0, pred = [False], iscorrect = [ True]
# 1296 true = 1, pred = [False], iscorrect = [False]
# 1297 true = 1, pred = [ True], iscorrect = [ True]
# 1298 true = 1, pred = [ True], iscorrect = [ True]
# 1299 true = 0, pred = [False], iscorrect = [ True]
# 1300 true = 1, pred = [False], iscorrect = [False]
# 1301 true = 0, pred = [False], iscorrect = [ True]
# 1302 true = 1, pred = [ True], iscorrect = [ True]
# 1303 true = 0, pred = [False], iscorrect = [ True]
# 1304 true = 0, pred = [ True], iscorrect = [False]
# 1305 true = 0, pred = [ True], iscorrect = [False]
# 1306 true = 1, pred = [False], iscorrect = [False]
# 1307 true = 0, pred = [False], iscorrect = [ True]
# 1308 true = 0, pred = [False], iscorrect = [ True]
# 1309 true = 1, pred = [ True], iscorrect = [ True]
# 1310 true = 1, pred = [ True], iscorrect = [ True]
# 1311 true = 1, pred = [ True], iscorrect = [ True]
# 1312 true = 1, pred = [ True], iscorrect = [ True]
# 1313 true = 1, pred = [ True], iscorrect = [ True]
# 1314 true = 1, pred = [ True], iscorrect = [ True]
# 1315 true = 1, pred = [False], iscorrect = [False]
# 1316 true = 1, pred = [ True], iscorrect = [ True]
# 1317 true = 0, pred = [False], iscorrect = [ True]
# 1318 true = 1, pred = [ True], iscorrect = [ True]
# 1319 true = 0, pred = [False], iscorrect = [ True]
# 1320 true = 1, pred = [False], iscorrect = [False]
# 1321 true = 0, pred = [False], iscorrect = [ True]
# 1322 true = 1, pred = [ True], iscorrect = [ True]
# 1323 true = 1, pred = [ True], iscorrect = [ True]
# 1324 true = 1, pred = [ True], iscorrect = [ True]
# 1325 true = 1, pred = [False], iscorrect = [False]
# 1326 true = 1, pred = [ True], iscorrect = [ True]
# 1327 true = 0, pred = [False], iscorrect = [ True]
# 1328 true = 1, pred = [ True], iscorrect = [ True]
# 1329 true = 1, pred = [ True], iscorrect = [ True]
# 1330 true = 0, pred = [False], iscorrect = [ True]
# 1331 true = 0, pred = [False], iscorrect = [ True]
# 1332 true = 1, pred = [False], iscorrect = [False]
# 1333 true = 1, pred = [ True], iscorrect = [ True]
# 1334 true = 1, pred = [ True], iscorrect = [ True]
# 1335 true = 0, pred = [ True], iscorrect = [False]
# 1336 true = 1, pred = [False], iscorrect = [False]
# 1337 true = 0, pred = [False], iscorrect = [ True]
# 1338 true = 0, pred = [False], iscorrect = [ True]
# 1339 true = 1, pred = [ True], iscorrect = [ True]
# 1340 true = 1, pred = [ True], iscorrect = [ True]
# 1341 true = 1, pred = [False], iscorrect = [False]
# 1342 true = 0, pred = [False], iscorrect = [ True]
# 1343 true = 0, pred = [False], iscorrect = [ True]
# 1344 true = 0, pred = [False], iscorrect = [ True]
# 1345 true = 1, pred = [ True], iscorrect = [ True]
# 1346 true = 1, pred = [ True], iscorrect = [ True]
# 1347 true = 0, pred = [False], iscorrect = [ True]
# 1348 true = 0, pred = [ True], iscorrect = [False]
# 1349 true = 1, pred = [ True], iscorrect = [ True]
# 1350 true = 0, pred = [False], iscorrect = [ True]
# 1351 true = 0, pred = [False], iscorrect = [ True]
# 1352 true = 1, pred = [ True], iscorrect = [ True]
# 1353 true = 1, pred = [ True], iscorrect = [ True]
# 1354 true = 1, pred = [ True], iscorrect = [ True]
# 1355 true = 1, pred = [ True], iscorrect = [ True]
# 1356 true = 1, pred = [False], iscorrect = [False]
# 1357 true = 1, pred = [False], iscorrect = [False]
# 1358 true = 0, pred = [False], iscorrect = [ True]
# 1359 true = 0, pred = [False], iscorrect = [ True]
# 1360 true = 1, pred = [ True], iscorrect = [ True]
# 1361 true = 0, pred = [ True], iscorrect = [False]
# 1362 true = 0, pred = [False], iscorrect = [ True]
# 1363 true = 0, pred = [False], iscorrect = [ True]
# 1364 true = 0, pred = [False], iscorrect = [ True]
# 1365 true = 1, pred = [ True], iscorrect = [ True]
# 1366 true = 1, pred = [False], iscorrect = [False]
# 1367 true = 0, pred = [False], iscorrect = [ True]
# 1368 true = 0, pred = [False], iscorrect = [ True]
# 1369 true = 1, pred = [ True], iscorrect = [ True]
# 1370 true = 1, pred = [False], iscorrect = [False]
# 1371 true = 0, pred = [False], iscorrect = [ True]
# 1372 true = 0, pred = [False], iscorrect = [ True]
# 1373 true = 1, pred = [ True], iscorrect = [ True]
# 1374 true = 1, pred = [False], iscorrect = [False]
# 1375 true = 1, pred = [ True], iscorrect = [ True]
# 1376 true = 0, pred = [False], iscorrect = [ True]
# 1377 true = 0, pred = [False], iscorrect = [ True]
# 1378 true = 0, pred = [False], iscorrect = [ True]
# 1379 true = 0, pred = [False], iscorrect = [ True]
# 1380 true = 1, pred = [False], iscorrect = [False]
# 1381 true = 1, pred = [ True], iscorrect = [ True]
# 1382 true = 1, pred = [ True], iscorrect = [ True]
# 1383 true = 0, pred = [False], iscorrect = [ True]
# 1384 true = 0, pred = [False], iscorrect = [ True]
# 1385 true = 0, pred = [False], iscorrect = [ True]
# 1386 true = 1, pred = [ True], iscorrect = [ True]
# 1387 true = 0, pred = [False], iscorrect = [ True]
# 1388 true = 0, pred = [False], iscorrect = [ True]
# 1389 true = 0, pred = [False], iscorrect = [ True]
# 1390 true = 1, pred = [ True], iscorrect = [ True]
# 1391 true = 1, pred = [ True], iscorrect = [ True]
# 1392 true = 1, pred = [False], iscorrect = [False]
# 1393 true = 1, pred = [ True], iscorrect = [ True]
# 1394 true = 1, pred = [ True], iscorrect = [ True]
# 1395 true = 1, pred = [ True], iscorrect = [ True]
# 1396 true = 0, pred = [ True], iscorrect = [False]
# 1397 true = 0, pred = [False], iscorrect = [ True]
# 1398 true = 0, pred = [False], iscorrect = [ True]
# 1399 true = 0, pred = [False], iscorrect = [ True]
# 1400 true = 0, pred = [False], iscorrect = [ True]
# 1401 true = 0, pred = [False], iscorrect = [ True]
# 1402 true = 0, pred = [False], iscorrect = [ True]
# 1403 true = 1, pred = [ True], iscorrect = [ True]
# 1404 true = 1, pred = [ True], iscorrect = [ True]
# 1405 true = 0, pred = [False], iscorrect = [ True]
# 1406 true = 1, pred = [False], iscorrect = [False]
# 1407 true = 1, pred = [ True], iscorrect = [ True]
# 1408 true = 0, pred = [False], iscorrect = [ True]
# 1409 true = 0, pred = [ True], iscorrect = [False]
# 1410 true = 1, pred = [False], iscorrect = [False]
# 1411 true = 1, pred = [ True], iscorrect = [ True]
# 1412 true = 0, pred = [ True], iscorrect = [False]
# 1413 true = 1, pred = [ True], iscorrect = [ True]
# 1414 true = 0, pred = [False], iscorrect = [ True]
# 1415 true = 0, pred = [False], iscorrect = [ True]
# 1416 true = 1, pred = [ True], iscorrect = [ True]
# 1417 true = 1, pred = [ True], iscorrect = [ True]
# 1418 true = 1, pred = [ True], iscorrect = [ True]
# 1419 true = 0, pred = [False], iscorrect = [ True]
# 1420 true = 1, pred = [ True], iscorrect = [ True]
# 1421 true = 1, pred = [ True], iscorrect = [ True]
# 1422 true = 1, pred = [ True], iscorrect = [ True]
# 1423 true = 0, pred = [False], iscorrect = [ True]
# 1424 true = 0, pred = [False], iscorrect = [ True]
# 1425 true = 1, pred = [ True], iscorrect = [ True]
# 1426 true = 0, pred = [False], iscorrect = [ True]
# 1427 true = 0, pred = [False], iscorrect = [ True]
# 1428 true = 1, pred = [ True], iscorrect = [ True]
# 1429 true = 1, pred = [False], iscorrect = [False]
# 1430 true = 1, pred = [ True], iscorrect = [ True]
# 1431 true = 1, pred = [ True], iscorrect = [ True]
# 1432 true = 0, pred = [False], iscorrect = [ True]
# 1433 true = 1, pred = [ True], iscorrect = [ True]
# 1434 true = 0, pred = [False], iscorrect = [ True]
# 1435 true = 0, pred = [False], iscorrect = [ True]
# 1436 true = 1, pred = [ True], iscorrect = [ True]
# 1437 true = 0, pred = [False], iscorrect = [ True]
# 1438 true = 1, pred = [False], iscorrect = [False]
# 1439 true = 1, pred = [ True], iscorrect = [ True]
# 1440 true = 0, pred = [False], iscorrect = [ True]
# 1441 true = 1, pred = [ True], iscorrect = [ True]
# 1442 true = 1, pred = [ True], iscorrect = [ True]
# 1443 true = 1, pred = [False], iscorrect = [False]
# 1444 true = 0, pred = [False], iscorrect = [ True]
# 1445 true = 0, pred = [False], iscorrect = [ True]
# 1446 true = 1, pred = [ True], iscorrect = [ True]
# 1447 true = 0, pred = [ True], iscorrect = [False]
# 1448 true = 1, pred = [ True], iscorrect = [ True]
# 1449 true = 1, pred = [ True], iscorrect = [ True]
# 1450 true = 1, pred = [False], iscorrect = [False]
# 1451 true = 1, pred = [ True], iscorrect = [ True]
# 1452 true = 0, pred = [False], iscorrect = [ True]
# 1453 true = 1, pred = [ True], iscorrect = [ True]
# 1454 true = 0, pred = [False], iscorrect = [ True]
# 1455 true = 1, pred = [ True], iscorrect = [ True]
# 1456 true = 1, pred = [False], iscorrect = [False]
# 1457 true = 1, pred = [ True], iscorrect = [ True]
# 1458 true = 0, pred = [False], iscorrect = [ True]
# 1459 true = 0, pred = [False], iscorrect = [ True]
# 1460 true = 1, pred = [ True], iscorrect = [ True]
# 1461 true = 0, pred = [False], iscorrect = [ True]
# 1462 true = 0, pred = [False], iscorrect = [ True]
# 1463 true = 0, pred = [False], iscorrect = [ True]
# 1464 true = 0, pred = [False], iscorrect = [ True]
# 1465 true = 1, pred = [ True], iscorrect = [ True]
# 1466 true = 0, pred = [False], iscorrect = [ True]
# 1467 true = 0, pred = [False], iscorrect = [ True]
# 1468 true = 0, pred = [ True], iscorrect = [False]
# 1469 true = 1, pred = [ True], iscorrect = [ True]
# 1470 true = 0, pred = [False], iscorrect = [ True]
# 1471 true = 1, pred = [ True], iscorrect = [ True]
# 1472 true = 0, pred = [False], iscorrect = [ True]
# 1473 true = 1, pred = [ True], iscorrect = [ True]
# 1474 true = 0, pred = [False], iscorrect = [ True]
# 1475 true = 0, pred = [ True], iscorrect = [False]
# 1476 true = 1, pred = [ True], iscorrect = [ True]
# 1477 true = 0, pred = [ True], iscorrect = [False]
# 1478 true = 1, pred = [ True], iscorrect = [ True]
# 1479 true = 1, pred = [False], iscorrect = [False]
# 1480 true = 0, pred = [False], iscorrect = [ True]
# 1481 true = 0, pred = [False], iscorrect = [ True]
# 1482 true = 0, pred = [False], iscorrect = [ True]
# 1483 true = 0, pred = [False], iscorrect = [ True]
# 1484 true = 1, pred = [ True], iscorrect = [ True]
# 1485 true = 0, pred = [False], iscorrect = [ True]
# 1486 true = 1, pred = [ True], iscorrect = [ True]
# 1487 true = 0, pred = [False], iscorrect = [ True]
# 1488 true = 0, pred = [False], iscorrect = [ True]
# 1489 true = 1, pred = [ True], iscorrect = [ True]
# 1490 true = 0, pred = [False], iscorrect = [ True]
# 1491 true = 0, pred = [False], iscorrect = [ True]
# 1492 true = 1, pred = [ True], iscorrect = [ True]
# 1493 true = 0, pred = [False], iscorrect = [ True]
# 1494 true = 1, pred = [ True], iscorrect = [ True]
# 1495 true = 1, pred = [False], iscorrect = [False]
# 1496 true = 1, pred = [ True], iscorrect = [ True]
# 1497 true = 0, pred = [False], iscorrect = [ True]
# 1498 true = 0, pred = [False], iscorrect = [ True]
# 1499 true = 1, pred = [ True], iscorrect = [ True]
# 1500 true = 1, pred = [False], iscorrect = [False]
# 1501 true = 1, pred = [ True], iscorrect = [ True]
# 1502 true = 0, pred = [False], iscorrect = [ True]
# 1503 true = 1, pred = [False], iscorrect = [False]
# 1504 true = 1, pred = [ True], iscorrect = [ True]
# 1505 true = 1, pred = [ True], iscorrect = [ True]
# 1506 true = 0, pred = [False], iscorrect = [ True]
# 1507 true = 0, pred = [False], iscorrect = [ True]
# 1508 true = 1, pred = [ True], iscorrect = [ True]
# 1509 true = 1, pred = [ True], iscorrect = [ True]
# 1510 true = 1, pred = [False], iscorrect = [False]
# 1511 true = 0, pred = [False], iscorrect = [ True]
# 1512 true = 1, pred = [ True], iscorrect = [ True]
# 1513 true = 1, pred = [False], iscorrect = [False]
# 1514 true = 0, pred = [False], iscorrect = [ True]
# 1515 true = 1, pred = [ True], iscorrect = [ True]
# 1516 true = 1, pred = [ True], iscorrect = [ True]
# 1517 true = 1, pred = [False], iscorrect = [False]

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(5, 5, figsize=(35, 35))
l=0
r=0

for i in range(25):
  found = False
  same_len_chunks = []

  for chunks in l_scores:
    if(len(chunks) == i+1):
      found=True
      same_len_chunks.append(chunks)

  if(found):
    mean_scores = np.mean(same_len_chunks, axis=0)
    plt.xticks(list(range(1,len(mean_scores)+1,1)))
    y = list(range(1,len(mean_scores)+1,1))
    axs[l,r].plot(y, mean_scores, marker='o', linestyle='dashed')
    xlabel_str = 'Chunk size ' + str(len(mean_scores)) + " (number of docs = " + str(len(same_len_chunks)) + ")"
    axs[l,r].set_xlabel(xlabel_str,fontsize = 15.0)
    axs[l,r].set_ylabel('Avg Occlusion Scores',fontsize = 15.0)
    r+=1
    if(r==5):
      l+=1
      r=0

#plt.savefig('/content/drive/MyDrive/Thesis/Models_whole_data/case_explanation/LSGBERT_bigru/occlusion_scores/occ_scores.png', bbox_inches='tight')
#plt.savefig('/content/drive/MyDrive/Thesis/Models_whole_data/case_explanation/LSGBERT_bigru/occlusion_scores/occ_scores.eps', format='eps', bbox_inches='tight')

# %%
#np.save("/content/drive/MyDrive/Thesis/Models_whole_data/case_explanation/LSGBERT_bigru/occlusion_scores/occwts.npy", l_scores)

# %%
len(l_scores)
# Out:
# 1516

# %%
len(l_scores[0])
# Out:
# 8
